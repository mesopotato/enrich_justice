# %%
import requests

url = "http://localhost:5010/api/parseDocument?renderFormat=all"
files = {'file': open('Y:\entscheidsuche\BE_Anwaltsaufsicht\PDF\BE_AK_001_AA-2012-98_2014-09-02.pdf', 'rb')}
response = requests.post(url, files=files)
print(response.json())
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\e'
# <>:4: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\mirela\AppData\Local\Temp\ipykernel_57812\456188595.py:4: SyntaxWarning: invalid escape sequence '\e'
#   files = {'file': open('Y:\entscheidsuche\BE_Anwaltsaufsicht\PDF\BE_AK_001_AA-2012-98_2014-09-02.pdf', 'rb')}
# ...
